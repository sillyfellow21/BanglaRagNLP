# %% [markdown]
# # বাংলা মেড-রাগ: স্ক্র্যাপিং ও প্রাথমিক EDA
# এই নোটবুকে বাংলা উইকিপিডিয়া থেকে স্বাস্থ্য বিষয়ক ডকুমেন্ট স্ক্র্যাপ করা হবে এবং মৌলিক বিশ্লেষণ করা হবে।

# %%
from banglamed_rag.scraper import run_scraper
from banglamed_rag.cleaner import clean_corpus
from banglamed_rag.utils import read_jsonl
from banglamed_rag.config import settings

# %%
docs = run_scraper(max_pages=200)
print(f"সংগ্রহ করা ডকুমেন্ট: {len(docs)}")

# %%
cleaned = clean_corpus()
print(f"পরিষ্কৃত চাঙ্ক: {len(cleaned)}")
sample = read_jsonl(settings.cleaned_corpus_path)[:3]
sample
